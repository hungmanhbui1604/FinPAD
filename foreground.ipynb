# %%
from foreground_extraction import extract_one
from visualization import visualize_foreground_extraction
from PIL import Image
import numpy as np

# %%
IMAGE_PATH = './Live/074TamRltlBmk.png'
BLOCK_SIZE = 5
DELTA = 15
KERNEL_SIZE = 5

# %%
pil = Image.open(IMAGE_PATH).convert('L')
original = np.array(pil).astype(np.uint8)

binarized, dilated, foreground_mask, foreground = extract_one(original, BLOCK_SIZE, DELTA, KERNEL_SIZE)

visualize_foreground_extraction(original, binarized, dilated, foreground_mask, foreground)
